# %%
"""
Code to convert all .dat files (ECG signals) in a folder to CSV format 
@author: Abhishek Patil
@modified by: Oscar, Kuan Ka Meng
"""

import wfdb #WaveForm-Database package. A library of tools for reading, writing, and processing WFDB signals and annotations.
import pandas as pd
import numpy as np
import glob2 as glob
import os

# %%
def create_dataset(person_id):
    db_folder = "ECGID_DB/"
    dataset_folder = "ECGID_DB_DATASET/"

    if (person_id < 10):
        person_path = "0" + str(person_id)
    else:
        person_path = str(person_id)

    person_folder = "Person_" + person_path + "/"
    

    dat_files=glob.glob(db_folder + person_folder + '*.dat') #Get list of all .dat files in the current folder
    df=pd.DataFrame(data=dat_files)
    df.to_csv("files_list_"+person_path+".csv",index=False,header=None) #Write the list to a CSV file
    files=pd.read_csv("files_list_"+person_path+".csv",header=None)
    print(dat_files)

    for i in range(0,len(files)):
        recordname=str(dat_files[i])
        temp=recordname.split('.')
        temp2=temp[0].split('/')
        recordname = temp2[2]

        print(recordname)

        record = wfdb.rdsamp(db_folder + person_folder + recordname) # rdsamp() returns the signal as a numpy array  
        record=np.asarray(record[0])
        path=dataset_folder + str(person_id) + "/" + recordname + ".csv"
        print(path)

        dataset_path = dataset_folder + str(person_id) + "/"

        if not os.path.exists(dataset_path):
            os.mkdir(dataset_path)

        np.savetxt(path,record,delimiter=",") #Writing the CSV for each record
        print("Files done: %s/%s"% (i+1,len(files)))

    print("\n [ " + person_folder + "] All files done!\n")

# %%
def main():
    for x in range(1,91):
        create_dataset(person_id=x)

# %%
if __name__ == "__main__":
    main()
# Out:
# ['ECGID_DB/Person_01/rec_8.dat', 'ECGID_DB/Person_01/rec_9.dat', 'ECGID_DB/Person_01/rec_18.dat', 'ECGID_DB/Person_01/rec_19.dat', 'ECGID_DB/Person_01/rec_20.dat', 'ECGID_DB/Person_01/rec_11.dat', 'ECGID_DB/Person_01/rec_10.dat', 'ECGID_DB/Person_01/rec_12.dat', 'ECGID_DB/Person_01/rec_13.dat', 'ECGID_DB/Person_01/rec_17.dat', 'ECGID_DB/Person_01/rec_16.dat', 'ECGID_DB/Person_01/rec_14.dat', 'ECGID_DB/Person_01/rec_15.dat', 'ECGID_DB/Person_01/rec_4.dat', 'ECGID_DB/Person_01/rec_5.dat', 'ECGID_DB/Person_01/rec_7.dat', 'ECGID_DB/Person_01/rec_6.dat', 'ECGID_DB/Person_01/rec_2.dat', 'ECGID_DB/Person_01/rec_3.dat', 'ECGID_DB/Person_01/rec_1.dat']
# rec_8
# ECGID_DB_DATASET/1/rec_8.csv
# Files done: 1/20
# rec_9
# ECGID_DB_DATASET/1/rec_9.csv
# Files done: 2/20
# rec_18
# ECGID_DB_DATASET/1/rec_18.csv
# Files done: 3/20
# rec_19
# ECGID_DB_DATASET/1/rec_19.csv
# Files done: 4/20
# rec_20
# ECGID_DB_DATASET/1/rec_20.csv
# Files done: 5/20
# rec_11
# ECGID_DB_DATASET/1/rec_11.csv
# Files done: 6/20
# rec_10
# ECGID_DB_DATASET/1/rec_10.csv
# Files done: 7/20
# rec_12
# ECGID_DB_DATASET/1/rec_12.csv
# Files done: 8/20
# rec_13
# ECGID_DB_DATASET/1/rec_13.csv
# Files done: 9/20
# rec_17
# ECGID_DB_DATASET/1/rec_17.csv
# Files done: 10/20
# rec_16
# ECGID_DB_DATASET/1/rec_16.csv
# Files done: 11/20
# rec_14
# ECGID_DB_DATASET/1/rec_14.csv
# Files done: 12/20
# rec_15
# ECGID_DB_DATASET/1/rec_15.csv
# Files done: 13/20
# rec_4
# ECGID_DB_DATASET/1/rec_4.csv
# Files done: 14/20
# rec_5
# ECGID_DB_DATASET/1/rec_5.csv
# Files done: 15/20
# rec_7
# ECGID_DB_DATASET/1/rec_7.csv
# Files done: 16/20
# rec_6
# ECGID_DB_DATASET/1/rec_6.csv
# Files done: 17/20
# rec_2
# ECGID_DB_DATASET/1/rec_2.csv
# Files done: 18/20
# rec_3
# ECGID_DB_DATASET/1/rec_3.csv
# Files done: 19/20
# rec_1
# ECGID_DB_DATASET/1/rec_1.csv
# Files done: 20/20
#
#  [ Person_01/] All files done!
#
# ['ECGID_DB/Person_02/rec_8.dat', 'ECGID_DB/Person_02/rec_9.dat', 'ECGID_DB/Person_02/rec_18.dat', 'ECGID_DB/Person_02/rec_19.dat', 'ECGID_DB/Person_02/rec_22.dat', 'ECGID_DB/Person_02/rec_21.dat', 'ECGID_DB/Person_02/rec_20.dat', 'ECGID_DB/Person_02/rec_11.dat', 'ECGID_DB/Person_02/rec_10.dat', 'ECGID_DB/Person_02/rec_12.dat', 'ECGID_DB/Person_02/rec_13.dat', 'ECGID_DB/Person_02/rec_17.dat', 'ECGID_DB/Person_02/rec_16.dat', 'ECGID_DB/Person_02/rec_14.dat', 'ECGID_DB/Person_02/rec_15.dat', 'ECGID_DB/Person_02/rec_4.dat', 'ECGID_DB/Person_02/rec_5.dat', 'ECGID_DB/Person_02/rec_7.dat', 'ECGID_DB/Person_02/rec_6.dat', 'ECGID_DB/Person_02/rec_2.dat', 'ECGID_DB/Person_02/rec_3.dat', 'ECGID_DB/Person_02/rec_1.dat']
# rec_8
# ECGID_DB_DATASET/2/rec_8.csv
# Files done: 1/22
# rec_9
# ECGID_DB_DATASET/2/rec_9.csv
# Files done: 2/22
# rec_18
# ECGID_DB_DATASET/2/rec_18.csv
# Files done: 3/22
# rec_19
# ECGID_DB_DATASET/2/rec_19.csv
# Files done: 4/22
# rec_22
# ECGID_DB_DATASET/2/rec_22.csv
# Files done: 5/22
# rec_21
# ECGID_DB_DATASET/2/rec_21.csv
# Files done: 6/22
# rec_20
# ECGID_DB_DATASET/2/rec_20.csv
# Files done: 7/22
# rec_11
# ECGID_DB_DATASET/2/rec_11.csv
# Files done: 8/22
# rec_10
# ECGID_DB_DATASET/2/rec_10.csv
# Files done: 9/22
# rec_12
# ECGID_DB_DATASET/2/rec_12.csv
# Files done: 10/22
# rec_13
# ECGID_DB_DATASET/2/rec_13.csv
# Files done: 11/22
# rec_17
# ECGID_DB_DATASET/2/rec_17.csv
# Files done: 12/22
# rec_16
# ECGID_DB_DATASET/2/rec_16.csv
# Files done: 13/22
# rec_14
# ECGID_DB_DATASET/2/rec_14.csv
# Files done: 14/22
# rec_15
# ECGID_DB_DATASET/2/rec_15.csv
# Files done: 15/22
# rec_4
# ECGID_DB_DATASET/2/rec_4.csv
# Files done: 16/22
# rec_5
# ECGID_DB_DATASET/2/rec_5.csv
# Files done: 17/22
# rec_7
# ECGID_DB_DATASET/2/rec_7.csv
# Files done: 18/22
# rec_6
# ECGID_DB_DATASET/2/rec_6.csv
# Files done: 19/22
# rec_2
# ECGID_DB_DATASET/2/rec_2.csv
# Files done: 20/22
# rec_3
# ECGID_DB_DATASET/2/rec_3.csv
# Files done: 21/22
# rec_1
# ECGID_DB_DATASET/2/rec_1.csv
# Files done: 22/22
#
#  [ Person_02/] All files done!
#
# ['ECGID_DB/Person_03/rec_4.dat', 'ECGID_DB/Person_03/rec_5.dat', 'ECGID_DB/Person_03/rec_2.dat', 'ECGID_DB/Person_03/rec_3.dat', 'ECGID_DB/Person_03/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/3/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/3/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/3/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/3/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/3/rec_1.csv
# Files done: 5/5
#
#  [ Person_03/] All files done!
#
# ['ECGID_DB/Person_04/rec_2.dat', 'ECGID_DB/Person_04/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/4/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/4/rec_1.csv
# Files done: 2/2
#
#  [ Person_04/] All files done!
#
# ['ECGID_DB/Person_05/rec_2.dat', 'ECGID_DB/Person_05/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/5/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/5/rec_1.csv
# Files done: 2/2
#
#  [ Person_05/] All files done!
#
# ['ECGID_DB/Person_06/rec_2.dat', 'ECGID_DB/Person_06/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/6/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/6/rec_1.csv
# Files done: 2/2
#
#  [ Person_06/] All files done!
#
# ['ECGID_DB/Person_07/rec_2.dat', 'ECGID_DB/Person_07/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/7/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/7/rec_1.csv
# Files done: 2/2
#
#  [ Person_07/] All files done!
#
# ['ECGID_DB/Person_08/rec_2.dat', 'ECGID_DB/Person_08/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/8/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/8/rec_1.csv
# Files done: 2/2
#
#  [ Person_08/] All files done!
#
# ['ECGID_DB/Person_09/rec_4.dat', 'ECGID_DB/Person_09/rec_5.dat', 'ECGID_DB/Person_09/rec_7.dat', 'ECGID_DB/Person_09/rec_6.dat', 'ECGID_DB/Person_09/rec_2.dat', 'ECGID_DB/Person_09/rec_3.dat', 'ECGID_DB/Person_09/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/9/rec_4.csv
# Files done: 1/7
# rec_5
# ECGID_DB_DATASET/9/rec_5.csv
# Files done: 2/7
# rec_7
# ECGID_DB_DATASET/9/rec_7.csv
# Files done: 3/7
# rec_6
# ECGID_DB_DATASET/9/rec_6.csv
# Files done: 4/7
# rec_2
# ECGID_DB_DATASET/9/rec_2.csv
# Files done: 5/7
# rec_3
# ECGID_DB_DATASET/9/rec_3.csv
# Files done: 6/7
# rec_1
# ECGID_DB_DATASET/9/rec_1.csv
# Files done: 7/7
#
#  [ Person_09/] All files done!
#
# ['ECGID_DB/Person_10/rec_4.dat', 'ECGID_DB/Person_10/rec_5.dat', 'ECGID_DB/Person_10/rec_2.dat', 'ECGID_DB/Person_10/rec_3.dat', 'ECGID_DB/Person_10/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/10/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/10/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/10/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/10/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/10/rec_1.csv
# Files done: 5/5
#
#  [ Person_10/] All files done!
#
# ['ECGID_DB/Person_11/rec_2.dat', 'ECGID_DB/Person_11/rec_3.dat', 'ECGID_DB/Person_11/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/11/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/11/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/11/rec_1.csv
# Files done: 3/3
#
#  [ Person_11/] All files done!
#
# ['ECGID_DB/Person_12/rec_2.dat', 'ECGID_DB/Person_12/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/12/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/12/rec_1.csv
# Files done: 2/2
#
#  [ Person_12/] All files done!
#
# ['ECGID_DB/Person_13/rec_2.dat', 'ECGID_DB/Person_13/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/13/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/13/rec_1.csv
# Files done: 2/2
#
#  [ Person_13/] All files done!
#
# ['ECGID_DB/Person_14/rec_2.dat', 'ECGID_DB/Person_14/rec_3.dat', 'ECGID_DB/Person_14/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/14/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/14/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/14/rec_1.csv
# Files done: 3/3
#
#  [ Person_14/] All files done!
#
# ['ECGID_DB/Person_15/rec_2.dat', 'ECGID_DB/Person_15/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/15/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/15/rec_1.csv
# Files done: 2/2
#
#  [ Person_15/] All files done!
#
# ['ECGID_DB/Person_16/rec_2.dat', 'ECGID_DB/Person_16/rec_3.dat', 'ECGID_DB/Person_16/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/16/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/16/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/16/rec_1.csv
# Files done: 3/3
#
#  [ Person_16/] All files done!
#
# ['ECGID_DB/Person_17/rec_2.dat', 'ECGID_DB/Person_17/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/17/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/17/rec_1.csv
# Files done: 2/2
#
#  [ Person_17/] All files done!
#
# ['ECGID_DB/Person_18/rec_2.dat', 'ECGID_DB/Person_18/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/18/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/18/rec_1.csv
# Files done: 2/2
#
#  [ Person_18/] All files done!
#
# ['ECGID_DB/Person_19/rec_2.dat', 'ECGID_DB/Person_19/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/19/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/19/rec_1.csv
# Files done: 2/2
#
#  [ Person_19/] All files done!
#
# ['ECGID_DB/Person_20/rec_2.dat', 'ECGID_DB/Person_20/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/20/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/20/rec_1.csv
# Files done: 2/2
#
#  [ Person_20/] All files done!
#
# ['ECGID_DB/Person_21/rec_2.dat', 'ECGID_DB/Person_21/rec_3.dat', 'ECGID_DB/Person_21/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/21/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/21/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/21/rec_1.csv
# Files done: 3/3
#
#  [ Person_21/] All files done!
#
# ['ECGID_DB/Person_22/rec_2.dat', 'ECGID_DB/Person_22/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/22/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/22/rec_1.csv
# Files done: 2/2
#
#  [ Person_22/] All files done!
#
# ['ECGID_DB/Person_23/rec_2.dat', 'ECGID_DB/Person_23/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/23/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/23/rec_1.csv
# Files done: 2/2
#
#  [ Person_23/] All files done!
#
# ['ECGID_DB/Person_24/rec_4.dat', 'ECGID_DB/Person_24/rec_5.dat', 'ECGID_DB/Person_24/rec_2.dat', 'ECGID_DB/Person_24/rec_3.dat', 'ECGID_DB/Person_24/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/24/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/24/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/24/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/24/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/24/rec_1.csv
# Files done: 5/5
#
#  [ Person_24/] All files done!
#
# ['ECGID_DB/Person_25/rec_4.dat', 'ECGID_DB/Person_25/rec_5.dat', 'ECGID_DB/Person_25/rec_2.dat', 'ECGID_DB/Person_25/rec_3.dat', 'ECGID_DB/Person_25/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/25/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/25/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/25/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/25/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/25/rec_1.csv
# Files done: 5/5
#
#  [ Person_25/] All files done!
#
# ['ECGID_DB/Person_26/rec_4.dat', 'ECGID_DB/Person_26/rec_2.dat', 'ECGID_DB/Person_26/rec_3.dat', 'ECGID_DB/Person_26/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/26/rec_4.csv
# Files done: 1/4
# rec_2
# ECGID_DB_DATASET/26/rec_2.csv
# Files done: 2/4
# rec_3
# ECGID_DB_DATASET/26/rec_3.csv
# Files done: 3/4
# rec_1
# ECGID_DB_DATASET/26/rec_1.csv
# Files done: 4/4
#
#  [ Person_26/] All files done!
#
# ['ECGID_DB/Person_27/rec_2.dat', 'ECGID_DB/Person_27/rec_3.dat', 'ECGID_DB/Person_27/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/27/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/27/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/27/rec_1.csv
# Files done: 3/3
#
#  [ Person_27/] All files done!
#
# ['ECGID_DB/Person_28/rec_4.dat', 'ECGID_DB/Person_28/rec_5.dat', 'ECGID_DB/Person_28/rec_2.dat', 'ECGID_DB/Person_28/rec_3.dat', 'ECGID_DB/Person_28/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/28/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/28/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/28/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/28/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/28/rec_1.csv
# Files done: 5/5
#
#  [ Person_28/] All files done!
#
# ['ECGID_DB/Person_29/rec_2.dat', 'ECGID_DB/Person_29/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/29/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/29/rec_1.csv
# Files done: 2/2
#
#  [ Person_29/] All files done!
#
# ['ECGID_DB/Person_30/rec_4.dat', 'ECGID_DB/Person_30/rec_5.dat', 'ECGID_DB/Person_30/rec_2.dat', 'ECGID_DB/Person_30/rec_3.dat', 'ECGID_DB/Person_30/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/30/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/30/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/30/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/30/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/30/rec_1.csv
# Files done: 5/5
#
#  [ Person_30/] All files done!
#
# ['ECGID_DB/Person_31/rec_2.dat', 'ECGID_DB/Person_31/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/31/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/31/rec_1.csv
# Files done: 2/2
#
#  [ Person_31/] All files done!
#
# ['ECGID_DB/Person_32/rec_4.dat', 'ECGID_DB/Person_32/rec_5.dat', 'ECGID_DB/Person_32/rec_6.dat', 'ECGID_DB/Person_32/rec_2.dat', 'ECGID_DB/Person_32/rec_3.dat', 'ECGID_DB/Person_32/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/32/rec_4.csv
# Files done: 1/6
# rec_5
# ECGID_DB_DATASET/32/rec_5.csv
# Files done: 2/6
# rec_6
# ECGID_DB_DATASET/32/rec_6.csv
# Files done: 3/6
# rec_2
# ECGID_DB_DATASET/32/rec_2.csv
# Files done: 4/6
# rec_3
# ECGID_DB_DATASET/32/rec_3.csv
# Files done: 5/6
# rec_1
# ECGID_DB_DATASET/32/rec_1.csv
# Files done: 6/6
#
#  [ Person_32/] All files done!
#
# ['ECGID_DB/Person_33/rec_2.dat', 'ECGID_DB/Person_33/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/33/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/33/rec_1.csv
# Files done: 2/2
#
#  [ Person_33/] All files done!
#
# ['ECGID_DB/Person_34/rec_4.dat', 'ECGID_DB/Person_34/rec_5.dat', 'ECGID_DB/Person_34/rec_2.dat', 'ECGID_DB/Person_34/rec_3.dat', 'ECGID_DB/Person_34/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/34/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/34/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/34/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/34/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/34/rec_1.csv
# Files done: 5/5
#
#  [ Person_34/] All files done!
#
# ['ECGID_DB/Person_35/rec_4.dat', 'ECGID_DB/Person_35/rec_5.dat', 'ECGID_DB/Person_35/rec_2.dat', 'ECGID_DB/Person_35/rec_3.dat', 'ECGID_DB/Person_35/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/35/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/35/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/35/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/35/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/35/rec_1.csv
# Files done: 5/5
#
#  [ Person_35/] All files done!
#
# ['ECGID_DB/Person_36/rec_4.dat', 'ECGID_DB/Person_36/rec_5.dat', 'ECGID_DB/Person_36/rec_2.dat', 'ECGID_DB/Person_36/rec_3.dat', 'ECGID_DB/Person_36/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/36/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/36/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/36/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/36/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/36/rec_1.csv
# Files done: 5/5
#
#  [ Person_36/] All files done!
#
# ['ECGID_DB/Person_37/rec_2.dat', 'ECGID_DB/Person_37/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/37/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/37/rec_1.csv
# Files done: 2/2
#
#  [ Person_37/] All files done!
#
# ['ECGID_DB/Person_38/rec_2.dat', 'ECGID_DB/Person_38/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/38/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/38/rec_1.csv
# Files done: 2/2
#
#  [ Person_38/] All files done!
#
# ['ECGID_DB/Person_39/rec_2.dat', 'ECGID_DB/Person_39/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/39/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/39/rec_1.csv
# Files done: 2/2
#
#  [ Person_39/] All files done!
#
# ['ECGID_DB/Person_40/rec_4.dat', 'ECGID_DB/Person_40/rec_2.dat', 'ECGID_DB/Person_40/rec_3.dat', 'ECGID_DB/Person_40/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/40/rec_4.csv
# Files done: 1/4
# rec_2
# ECGID_DB_DATASET/40/rec_2.csv
# Files done: 2/4
# rec_3
# ECGID_DB_DATASET/40/rec_3.csv
# Files done: 3/4
# rec_1
# ECGID_DB_DATASET/40/rec_1.csv
# Files done: 4/4
#
#  [ Person_40/] All files done!
#
# ['ECGID_DB/Person_41/rec_2.dat', 'ECGID_DB/Person_41/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/41/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/41/rec_1.csv
# Files done: 2/2
#
#  [ Person_41/] All files done!
#
# ['ECGID_DB/Person_42/rec_4.dat', 'ECGID_DB/Person_42/rec_2.dat', 'ECGID_DB/Person_42/rec_3.dat', 'ECGID_DB/Person_42/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/42/rec_4.csv
# Files done: 1/4
# rec_2
# ECGID_DB_DATASET/42/rec_2.csv
# Files done: 2/4
# rec_3
# ECGID_DB_DATASET/42/rec_3.csv
# Files done: 3/4
# rec_1
# ECGID_DB_DATASET/42/rec_1.csv
# Files done: 4/4
#
#  [ Person_42/] All files done!
#
# ['ECGID_DB/Person_43/rec_2.dat', 'ECGID_DB/Person_43/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/43/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/43/rec_1.csv
# Files done: 2/2
#
#  [ Person_43/] All files done!
#
# ['ECGID_DB/Person_44/rec_2.dat', 'ECGID_DB/Person_44/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/44/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/44/rec_1.csv
# Files done: 2/2
#
#  [ Person_44/] All files done!
#
# ['ECGID_DB/Person_45/rec_2.dat', 'ECGID_DB/Person_45/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/45/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/45/rec_1.csv
# Files done: 2/2
#
#  [ Person_45/] All files done!
#
# ['ECGID_DB/Person_46/rec_4.dat', 'ECGID_DB/Person_46/rec_5.dat', 'ECGID_DB/Person_46/rec_2.dat', 'ECGID_DB/Person_46/rec_3.dat', 'ECGID_DB/Person_46/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/46/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/46/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/46/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/46/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/46/rec_1.csv
# Files done: 5/5
#
#  [ Person_46/] All files done!
#
# ['ECGID_DB/Person_47/rec_2.dat', 'ECGID_DB/Person_47/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/47/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/47/rec_1.csv
# Files done: 2/2
#
#  [ Person_47/] All files done!
#
# ['ECGID_DB/Person_48/rec_2.dat', 'ECGID_DB/Person_48/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/48/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/48/rec_1.csv
# Files done: 2/2
#
#  [ Person_48/] All files done!
#
# ['ECGID_DB/Person_49/rec_2.dat', 'ECGID_DB/Person_49/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/49/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/49/rec_1.csv
# Files done: 2/2
#
#  [ Person_49/] All files done!
#
# ['ECGID_DB/Person_50/rec_2.dat', 'ECGID_DB/Person_50/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/50/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/50/rec_1.csv
# Files done: 2/2
#
#  [ Person_50/] All files done!
#
# ['ECGID_DB/Person_51/rec_4.dat', 'ECGID_DB/Person_51/rec_2.dat', 'ECGID_DB/Person_51/rec_3.dat', 'ECGID_DB/Person_51/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/51/rec_4.csv
# Files done: 1/4
# rec_2
# ECGID_DB_DATASET/51/rec_2.csv
# Files done: 2/4
# rec_3
# ECGID_DB_DATASET/51/rec_3.csv
# Files done: 3/4
# rec_1
# ECGID_DB_DATASET/51/rec_1.csv
# Files done: 4/4
#
#  [ Person_51/] All files done!
#
# ['ECGID_DB/Person_52/rec_8.dat', 'ECGID_DB/Person_52/rec_9.dat', 'ECGID_DB/Person_52/rec_11.dat', 'ECGID_DB/Person_52/rec_10.dat', 'ECGID_DB/Person_52/rec_4.dat', 'ECGID_DB/Person_52/rec_5.dat', 'ECGID_DB/Person_52/rec_7.dat', 'ECGID_DB/Person_52/rec_6.dat', 'ECGID_DB/Person_52/rec_2.dat', 'ECGID_DB/Person_52/rec_3.dat', 'ECGID_DB/Person_52/rec_1.dat']
# rec_8
# ECGID_DB_DATASET/52/rec_8.csv
# Files done: 1/11
# rec_9
# ECGID_DB_DATASET/52/rec_9.csv
# Files done: 2/11
# rec_11
# ECGID_DB_DATASET/52/rec_11.csv
# Files done: 3/11
# rec_10
# ECGID_DB_DATASET/52/rec_10.csv
# Files done: 4/11
# rec_4
# ECGID_DB_DATASET/52/rec_4.csv
# Files done: 5/11
# rec_5
# ECGID_DB_DATASET/52/rec_5.csv
# Files done: 6/11
# rec_7
# ECGID_DB_DATASET/52/rec_7.csv
# Files done: 7/11
# rec_6
# ECGID_DB_DATASET/52/rec_6.csv
# Files done: 8/11
# rec_2
# ECGID_DB_DATASET/52/rec_2.csv
# Files done: 9/11
# rec_3
# ECGID_DB_DATASET/52/rec_3.csv
# Files done: 10/11
# rec_1
# ECGID_DB_DATASET/52/rec_1.csv
# Files done: 11/11
#
#  [ Person_52/] All files done!
#
# ['ECGID_DB/Person_53/rec_4.dat', 'ECGID_DB/Person_53/rec_5.dat', 'ECGID_DB/Person_53/rec_2.dat', 'ECGID_DB/Person_53/rec_3.dat', 'ECGID_DB/Person_53/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/53/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/53/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/53/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/53/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/53/rec_1.csv
# Files done: 5/5
#
#  [ Person_53/] All files done!
#
# ['ECGID_DB/Person_54/rec_2.dat', 'ECGID_DB/Person_54/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/54/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/54/rec_1.csv
# Files done: 2/2
#
#  [ Person_54/] All files done!
#
# ['ECGID_DB/Person_55/rec_2.dat', 'ECGID_DB/Person_55/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/55/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/55/rec_1.csv
# Files done: 2/2
#
#  [ Person_55/] All files done!
#
# ['ECGID_DB/Person_56/rec_2.dat', 'ECGID_DB/Person_56/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/56/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/56/rec_1.csv
# Files done: 2/2
#
#  [ Person_56/] All files done!
#
# ['ECGID_DB/Person_57/rec_2.dat', 'ECGID_DB/Person_57/rec_3.dat', 'ECGID_DB/Person_57/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/57/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/57/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/57/rec_1.csv
# Files done: 3/3
#
#  [ Person_57/] All files done!
#
# ['ECGID_DB/Person_58/rec_2.dat', 'ECGID_DB/Person_58/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/58/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/58/rec_1.csv
# Files done: 2/2
#
#  [ Person_58/] All files done!
#
# ['ECGID_DB/Person_59/rec_4.dat', 'ECGID_DB/Person_59/rec_5.dat', 'ECGID_DB/Person_59/rec_2.dat', 'ECGID_DB/Person_59/rec_3.dat', 'ECGID_DB/Person_59/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/59/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/59/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/59/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/59/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/59/rec_1.csv
# Files done: 5/5
#
#  [ Person_59/] All files done!
#
# ['ECGID_DB/Person_60/rec_2.dat', 'ECGID_DB/Person_60/rec_3.dat', 'ECGID_DB/Person_60/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/60/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/60/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/60/rec_1.csv
# Files done: 3/3
#
#  [ Person_60/] All files done!
#
# ['ECGID_DB/Person_61/rec_4.dat', 'ECGID_DB/Person_61/rec_2.dat', 'ECGID_DB/Person_61/rec_3.dat', 'ECGID_DB/Person_61/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/61/rec_4.csv
# Files done: 1/4
# rec_2
# ECGID_DB_DATASET/61/rec_2.csv
# Files done: 2/4
# rec_3
# ECGID_DB_DATASET/61/rec_3.csv
# Files done: 3/4
# rec_1
# ECGID_DB_DATASET/61/rec_1.csv
# Files done: 4/4
#
#  [ Person_61/] All files done!
#
# ['ECGID_DB/Person_62/rec_2.dat', 'ECGID_DB/Person_62/rec_3.dat', 'ECGID_DB/Person_62/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/62/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/62/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/62/rec_1.csv
# Files done: 3/3
#
#  [ Person_62/] All files done!
#
# ['ECGID_DB/Person_63/rec_4.dat', 'ECGID_DB/Person_63/rec_5.dat', 'ECGID_DB/Person_63/rec_6.dat', 'ECGID_DB/Person_63/rec_2.dat', 'ECGID_DB/Person_63/rec_3.dat', 'ECGID_DB/Person_63/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/63/rec_4.csv
# Files done: 1/6
# rec_5
# ECGID_DB_DATASET/63/rec_5.csv
# Files done: 2/6
# rec_6
# ECGID_DB_DATASET/63/rec_6.csv
# Files done: 3/6
# rec_2
# ECGID_DB_DATASET/63/rec_2.csv
# Files done: 4/6
# rec_3
# ECGID_DB_DATASET/63/rec_3.csv
# Files done: 5/6
# rec_1
# ECGID_DB_DATASET/63/rec_1.csv
# Files done: 6/6
#
#  [ Person_63/] All files done!
#
# ['ECGID_DB/Person_64/rec_2.dat', 'ECGID_DB/Person_64/rec_3.dat', 'ECGID_DB/Person_64/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/64/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/64/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/64/rec_1.csv
# Files done: 3/3
#
#  [ Person_64/] All files done!
#
# ['ECGID_DB/Person_65/rec_2.dat', 'ECGID_DB/Person_65/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/65/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/65/rec_1.csv
# Files done: 2/2
#
#  [ Person_65/] All files done!
#
# ['ECGID_DB/Person_66/rec_2.dat', 'ECGID_DB/Person_66/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/66/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/66/rec_1.csv
# Files done: 2/2
#
#  [ Person_66/] All files done!
#
# ['ECGID_DB/Person_67/rec_2.dat', 'ECGID_DB/Person_67/rec_3.dat', 'ECGID_DB/Person_67/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/67/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/67/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/67/rec_1.csv
# Files done: 3/3
#
#  [ Person_67/] All files done!
#
# ['ECGID_DB/Person_68/rec_2.dat', 'ECGID_DB/Person_68/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/68/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/68/rec_1.csv
# Files done: 2/2
#
#  [ Person_68/] All files done!
#
# ['ECGID_DB/Person_69/rec_2.dat', 'ECGID_DB/Person_69/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/69/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/69/rec_1.csv
# Files done: 2/2
#
#  [ Person_69/] All files done!
#
# ['ECGID_DB/Person_70/rec_2.dat', 'ECGID_DB/Person_70/rec_3.dat', 'ECGID_DB/Person_70/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/70/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/70/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/70/rec_1.csv
# Files done: 3/3
#
#  [ Person_70/] All files done!
#
# ['ECGID_DB/Person_71/rec_4.dat', 'ECGID_DB/Person_71/rec_5.dat', 'ECGID_DB/Person_71/rec_2.dat', 'ECGID_DB/Person_71/rec_3.dat', 'ECGID_DB/Person_71/rec_1.dat']
# rec_4
# ECGID_DB_DATASET/71/rec_4.csv
# Files done: 1/5
# rec_5
# ECGID_DB_DATASET/71/rec_5.csv
# Files done: 2/5
# rec_2
# ECGID_DB_DATASET/71/rec_2.csv
# Files done: 3/5
# rec_3
# ECGID_DB_DATASET/71/rec_3.csv
# Files done: 4/5
# rec_1
# ECGID_DB_DATASET/71/rec_1.csv
# Files done: 5/5
#
#  [ Person_71/] All files done!
#
# ['ECGID_DB/Person_72/rec_8.dat', 'ECGID_DB/Person_72/rec_4.dat', 'ECGID_DB/Person_72/rec_5.dat', 'ECGID_DB/Person_72/rec_7.dat', 'ECGID_DB/Person_72/rec_6.dat', 'ECGID_DB/Person_72/rec_2.dat', 'ECGID_DB/Person_72/rec_3.dat', 'ECGID_DB/Person_72/rec_1.dat']
# rec_8
# ECGID_DB_DATASET/72/rec_8.csv
# Files done: 1/8
# rec_4
# ECGID_DB_DATASET/72/rec_4.csv
# Files done: 2/8
# rec_5
# ECGID_DB_DATASET/72/rec_5.csv
# Files done: 3/8
# rec_7
# ECGID_DB_DATASET/72/rec_7.csv
# Files done: 4/8
# rec_6
# ECGID_DB_DATASET/72/rec_6.csv
# Files done: 5/8
# rec_2
# ECGID_DB_DATASET/72/rec_2.csv
# Files done: 6/8
# rec_3
# ECGID_DB_DATASET/72/rec_3.csv
# Files done: 7/8
# rec_1
# ECGID_DB_DATASET/72/rec_1.csv
# Files done: 8/8
#
#  [ Person_72/] All files done!
#
# ['ECGID_DB/Person_73/rec_2.dat', 'ECGID_DB/Person_73/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/73/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/73/rec_1.csv
# Files done: 2/2
#
#  [ Person_73/] All files done!
#
# ['ECGID_DB/Person_74/rec_1.dat']
# rec_1
# ECGID_DB_DATASET/74/rec_1.csv
# Files done: 1/1
#
#  [ Person_74/] All files done!
#
# ['ECGID_DB/Person_75/rec_2.dat', 'ECGID_DB/Person_75/rec_3.dat', 'ECGID_DB/Person_75/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/75/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/75/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/75/rec_1.csv
# Files done: 3/3
#
#  [ Person_75/] All files done!
#
# ['ECGID_DB/Person_76/rec_2.dat', 'ECGID_DB/Person_76/rec_3.dat', 'ECGID_DB/Person_76/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/76/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/76/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/76/rec_1.csv
# Files done: 3/3
#
#  [ Person_76/] All files done!
#
# ['ECGID_DB/Person_77/rec_2.dat', 'ECGID_DB/Person_77/rec_3.dat', 'ECGID_DB/Person_77/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/77/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/77/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/77/rec_1.csv
# Files done: 3/3
#
#  [ Person_77/] All files done!
#
# ['ECGID_DB/Person_78/rec_2.dat', 'ECGID_DB/Person_78/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/78/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/78/rec_1.csv
# Files done: 2/2
#
#  [ Person_78/] All files done!
#
# ['ECGID_DB/Person_79/rec_2.dat', 'ECGID_DB/Person_79/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/79/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/79/rec_1.csv
# Files done: 2/2
#
#  [ Person_79/] All files done!
#
# ['ECGID_DB/Person_80/rec_2.dat', 'ECGID_DB/Person_80/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/80/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/80/rec_1.csv
# Files done: 2/2
#
#  [ Person_80/] All files done!
#
# ['ECGID_DB/Person_81/rec_2.dat', 'ECGID_DB/Person_81/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/81/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/81/rec_1.csv
# Files done: 2/2
#
#  [ Person_81/] All files done!
#
# ['ECGID_DB/Person_82/rec_2.dat', 'ECGID_DB/Person_82/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/82/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/82/rec_1.csv
# Files done: 2/2
#
#  [ Person_82/] All files done!
#
# ['ECGID_DB/Person_83/rec_2.dat', 'ECGID_DB/Person_83/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/83/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/83/rec_1.csv
# Files done: 2/2
#
#  [ Person_83/] All files done!
#
# ['ECGID_DB/Person_84/rec_2.dat', 'ECGID_DB/Person_84/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/84/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/84/rec_1.csv
# Files done: 2/2
#
#  [ Person_84/] All files done!
#
# ['ECGID_DB/Person_85/rec_2.dat', 'ECGID_DB/Person_85/rec_3.dat', 'ECGID_DB/Person_85/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/85/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/85/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/85/rec_1.csv
# Files done: 3/3
#
#  [ Person_85/] All files done!
#
# ['ECGID_DB/Person_86/rec_2.dat', 'ECGID_DB/Person_86/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/86/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/86/rec_1.csv
# Files done: 2/2
#
#  [ Person_86/] All files done!
#
# ['ECGID_DB/Person_87/rec_2.dat', 'ECGID_DB/Person_87/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/87/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/87/rec_1.csv
# Files done: 2/2
#
#  [ Person_87/] All files done!
#
# ['ECGID_DB/Person_88/rec_2.dat', 'ECGID_DB/Person_88/rec_3.dat', 'ECGID_DB/Person_88/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/88/rec_2.csv
# Files done: 1/3
# rec_3
# ECGID_DB_DATASET/88/rec_3.csv
# Files done: 2/3
# rec_1
# ECGID_DB_DATASET/88/rec_1.csv
# Files done: 3/3
#
#  [ Person_88/] All files done!
#
# ['ECGID_DB/Person_89/rec_2.dat', 'ECGID_DB/Person_89/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/89/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/89/rec_1.csv
# Files done: 2/2
#
#  [ Person_89/] All files done!
#
# ['ECGID_DB/Person_90/rec_2.dat', 'ECGID_DB/Person_90/rec_1.dat']
# rec_2
# ECGID_DB_DATASET/90/rec_2.csv
# Files done: 1/2
# rec_1
# ECGID_DB_DATASET/90/rec_1.csv
# Files done: 2/2
#
#  [ Person_90/] All files done!
